# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 2.5, 3, 4]
y = [1, 4, 7, 9, 15]
plt.plot(x, y, 'ro')
plt.axis([0, 6, 0, 20])
# Out:
# [0, 6, 0, 20]

# %%
plt.plot(x, y, 'ro')
plt.axis([0, 6, 0, 20])
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)))
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import clear_output
from six.moves import urllib
import tensorflow.compat.v2.feature_column as fc

import tensorflow as tf

# %%
dftrain = pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/train.csv') # training data
dfeval = pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/eval.csv') # testing data
y_train = dftrain.pop('survived')
y_eval = dfeval.pop('survived')

# %%
dftrain.age.hist(bins=20)

# %%
dftrain.sex.value_counts().plot(kind='bar')

# %%
pd.concat([dftrain, y_train], axis=1).groupby('sex').survived.mean().plot(kind='barh').set_xlabel('% survive')
# Out:
# Text(0.5, 0, '% survive')

# %% [markdown]
# ## Feature Columns

# %%
CATEGORICAL_COLUMNS = [
    'sex', 'n_siblings_spouses', 'parch', 'class', 'deck',
    'embark_town', 'alone'
]
NUMERIC_COLUMNS = ['age', 'fare']

feature_columns = []

for feature_name in CATEGORICAL_COLUMNS:
    vocabulary = dftrain[feature_name].unique()
    feature_columns.append(tf.feature_column.categorical_column_with_vocabulary_list(feature_name, vocabulary))

for feature_name in NUMERIC_COLUMNS:
    feature_columns.append(tf.feature_column.numeric_column(feature_name, dtype=tf.float32))

feature_columns
# Out:
# [VocabularyListCategoricalColumn(key='sex', vocabulary_list=('male', 'female'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='n_siblings_spouses', vocabulary_list=(1, 0, 3, 4, 2, 5, 8), dtype=tf.int64, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='parch', vocabulary_list=(0, 1, 2, 5, 3, 4), dtype=tf.int64, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='class', vocabulary_list=('Third', 'First', 'Second'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='deck', vocabulary_list=('unknown', 'C', 'G', 'A', 'B', 'D', 'F', 'E'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='embark_town', vocabulary_list=('Southampton', 'Cherbourg', 'Queenstown', 'unknown'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='alone', vocabulary_list=('n', 'y'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  NumericColumn(key='age', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='fare', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %% [markdown]
# ### Input Function

# %%
def make_input_fn(data_df, label_df, num_epochs=10, shuffle=True, batch_size=32):
    def input_function(): # inner function, this will be returned
        ds = tf.data.Dataset.from_tensor_slices((dict(data_df), label_df))
        if shuffle:
            ds = ds.shuffle(1000)  # randomize order of data
        ds = ds.batch(batch_size).repeat(num_epochs)  # split dataset into batches of 32 and repeat process for number of epochs
        return ds
    return input_function

train_input_fn = make_input_fn(dftrain, y_train)  # here we will call the input_function that was returned to us to get a dataset object we can feed to the model
eval_input_fn = make_input_fn(dfeval, y_eval, num_epochs=1, shuffle=False)

# %% [markdown]
# ## Creating the Model

# %%
linear_est = tf.estimator.LinearClassifier(feature_columns=feature_columns)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/93/6v8bj28n2qd703tlw3s9vkb40000gn/T/tmpxg6330vs
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/93/6v8bj28n2qd703tlw3s9vkb40000gn/T/tmpxg6330vs', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fd064a99690>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %% [markdown]
# ### Training the Model

# %%
linear_est.train(train_input_fn)
result = linear_est.evaluate(eval_input_fn)

clear_output()
print(result['accuracy'])
# Out:
# 0.7537879

# %%
pred_dicts = list(linear_est.predict(eval_input_fn))
probs = pd.Series([pred['probabilities'][1] for pred in pred_dicts])

probs.plot(kind='hist', bins=20, title='predicted probabilities')
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer linear/linear_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/93/6v8bj28n2qd703tlw3s9vkb40000gn/T/tmpxg6330vs/model.ckpt-200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %% [markdown]
# ### Classification

# %%
CSV_COLUMN_NAMES = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Species']
SPECIES = ['Setosa', 'Versicolor', 'Virginica']

# %%
train_path = tf.keras.utils.get_file(
    "iris_training.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_training.csv")
test_path = tf.keras.utils.get_file(
    "iris_test.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_test.csv")

train = pd.read_csv(train_path, names=CSV_COLUMN_NAMES, header=0)
test = pd.read_csv(test_path, names=CSV_COLUMN_NAMES, header=0)

# %%
train.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth  Species
# 0          6.4         2.8          5.6         2.2        2
# 1          5.0         2.3          3.3         1.0        1
# 2          4.9         2.5          4.5         1.7        2
# 3          4.9         3.1          1.5         0.1        0
# 4          5.7         3.8          1.7         0.3        0

# %%
train_y = train.pop('Species')
test_y = test.pop('Species')
train.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth
# 0          6.4         2.8          5.6         2.2
# 1          5.0         2.3          3.3         1.0
# 2          4.9         2.5          4.5         1.7
# 3          4.9         3.1          1.5         0.1
# 4          5.7         3.8          1.7         0.3

# %%
train.shape
# Out:
# (120, 4)

# %%
def input_fn(features, labels, training=True, batch_size=256):
    # Convert the inputs to a Dataset.
    dataset = tf.data.Dataset.from_tensor_slices((dict(features), labels))
    
    # Shuffle and repeat if you are in training mode.
    if training:
        dataset = dataset.shuffle(1000).repeat()
    
    return dataset.batch(batch_size)

# %% [markdown]
# ### Feature Columns

# %%
my_feature_columns = []
for key in train.keys():
    my_feature_columns.append(tf.feature_column.numeric_column(key=key))
print(my_feature_columns)
# Out:
# [NumericColumn(key='SepalLength', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='SepalWidth', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='PetalLength', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='PetalWidth', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %%
# Build a DNN with 2 hidden layers with 30 and 10 hidden nodes each.
classifier = tf.estimator.DNNClassifier(
    feature_columns=my_feature_columns,
    # Two hidden layers of 30 and 10 nodes respectively.
    hidden_units=[30, 10],
    # The model must choose between 3 classes.
    n_classes=3
)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/93/6v8bj28n2qd703tlw3s9vkb40000gn/T/tmp3_49jypx
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/93/6v8bj28n2qd703tlw3s9vkb40000gn/T/tmp3_49jypx', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fd065f70410>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
classifier.train(
    input_fn=lambda: input_fn(train, train_y, training=True),
    steps=5000
)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /var/folders/93/6v8bj28n2qd703tlw3s9vkb40000gn/T/tmp3_49jypx/model.ckpt.
# INFO:tensorflow:loss = 2.1340787, step = 0
# INFO:tensorflow:global_step/sec: 308.2
# INFO:tensorflow:loss = 1.3765991, step = 100 (0.326 sec)
# INFO:tensorflow:global_step/sec: 436.397
# INFO:tensorflow:loss = 1.1735345, step = 200 (0.228 sec)
# INFO:tensorflow:global_step/sec: 422.391
# INFO:tensorflow:loss = 1.0644253, step = 300 (0.237 sec)
# INFO:tensorflow:global_step/sec: 355.775
# INFO:tensorflow:loss = 1.0025885, step = 400 (0.282 sec)
# INFO:tensorflow:global_step/sec: 343.348
# INFO:tensorflow:loss = 0.9619821, step = 500 (0.291 sec)
# INFO:tensorflow:global_step/sec: 394.328
# INFO:tensorflow:loss = 0.92207515, step = 600 (0.253 sec)
# INFO:tensorflow:global_step/sec: 416.79
# INFO:tensorflow:loss = 0.907616, step = 700 (0.240 sec)
# INFO:tensorflow:global_step/sec: 309.628
# INFO:tensorflow:loss = 0.89763415, step = 800 (0.323 sec)
# INFO:tensorflow:global_step/sec: 393.342
# INFO:tensorflow:loss = 0.87873054, step = 900 (0.253 sec)
# INFO:tensorflow:global_step/sec: 427.921
# INFO:tensorflow:loss = 0.8671398, step = 1000 (0.234 sec)
# INFO:tensorflow:global_step/sec: 454.065
# INFO:tensorflow:loss = 0.8471229, step = 1100 (0.220 sec)
# INFO:tensorflow:global_step/sec: 410.711
# INFO:tensorflow:loss = 0.8505676, step = 1200 (0.244 sec)
# INFO:tensorflow:global_step/sec: 374.609
# INFO:tensorflow:loss = 0.82973015, step = 1300 (0.267 sec)
# INFO:tensorflow:global_step/sec: 409.212
# INFO:tensorflow:loss = 0.83174896, step = 1400 (0.245 sec)
# INFO:tensorflow:global_step/sec: 420.283
# INFO:tensorflow:loss = 0.8373975, step = 1500 (0.237 sec)
# INFO:tensorflow:global_step/sec: 433.175
# INFO:tensorflow:loss = 0.8366467, step = 1600 (0.231 sec)
# INFO:tensorflow:global_step/sec: 453.095
# INFO:tensorflow:loss = 0.8197597, step = 1700 (0.220 sec)
# INFO:tensorflow:global_step/sec: 419.488
# INFO:tensorflow:loss = 0.8058566, step = 1800 (0.238 sec)
# INFO:tensorflow:global_step/sec: 425.1
# INFO:tensorflow:loss = 0.807473, step = 1900 (0.235 sec)
# INFO:tensorflow:global_step/sec: 388.419
# INFO:tensorflow:loss = 0.7772667, step = 2000 (0.258 sec)
# INFO:tensorflow:global_step/sec: 331.268
# INFO:tensorflow:loss = 0.782218, step = 2100 (0.302 sec)
# INFO:tensorflow:global_step/sec: 397.825
# INFO:tensorflow:loss = 0.7709197, step = 2200 (0.251 sec)
# INFO:tensorflow:global_step/sec: 428.556
# INFO:tensorflow:loss = 0.76143074, step = 2300 (0.233 sec)
# INFO:tensorflow:global_step/sec: 398.702
# INFO:tensorflow:loss = 0.75742424, step = 2400 (0.251 sec)
# INFO:tensorflow:global_step/sec: 395.38
# INFO:tensorflow:loss = 0.7507894, step = 2500 (0.253 sec)
# INFO:tensorflow:global_step/sec: 396.12
# INFO:tensorflow:loss = 0.7472894, step = 2600 (0.252 sec)
# INFO:tensorflow:global_step/sec: 421.336
# INFO:tensorflow:loss = 0.7353101, step = 2700 (0.238 sec)
# INFO:tensorflow:global_step/sec: 392.699
# INFO:tensorflow:loss = 0.72498894, step = 2800 (0.254 sec)
# INFO:tensorflow:global_step/sec: 344.93
# INFO:tensorflow:loss = 0.7270318, step = 2900 (0.290 sec)
# INFO:tensorflow:global_step/sec: 347.438
# INFO:tensorflow:loss = 0.737925, step = 3000 (0.288 sec)
# INFO:tensorflow:global_step/sec: 345.212
# INFO:tensorflow:loss = 0.7106985, step = 3100 (0.289 sec)
# INFO:tensorflow:global_step/sec: 375.796
# INFO:tensorflow:loss = 0.7432575, step = 3200 (0.266 sec)
# INFO:tensorflow:global_step/sec: 372.376
# INFO:tensorflow:loss = 0.7042887, step = 3300 (0.268 sec)
# INFO:tensorflow:global_step/sec: 334.158
# INFO:tensorflow:loss = 0.6930384, step = 3400 (0.299 sec)
# INFO:tensorflow:global_step/sec: 395.523
# INFO:tensorflow:loss = 0.7124746, step = 3500 (0.253 sec)
# INFO:tensorflow:global_step/sec: 390.689
# INFO:tensorflow:loss = 0.6854433, step = 3600 (0.258 sec)
# INFO:tensorflow:global_step/sec: 401.908
# INFO:tensorflow:loss = 0.68919384, step = 3700 (0.248 sec)
# INFO:tensorflow:global_step/sec: 443.927
# INFO:tensorflow:loss = 0.7100513, step = 3800 (0.225 sec)
# INFO:tensorflow:global_step/sec: 453.304
# INFO:tensorflow:loss = 0.6878375, step = 3900 (0.221 sec)
# INFO:tensorflow:global_step/sec: 451.688
# INFO:tensorflow:loss = 0.68168116, step = 4000 (0.222 sec)
# INFO:tensorflow:global_step/sec: 432.157
# INFO:tensorflow:loss = 0.66872716, step = 4100 (0.230 sec)
# INFO:tensorflow:global_step/sec: 431.471
# INFO:tensorflow:loss = 0.6791221, step = 4200 (0.232 sec)
# INFO:tensorflow:global_step/sec: 397.189
# INFO:tensorflow:loss = 0.6726934, step = 4300 (0.252 sec)
# INFO:tensorflow:global_step/sec: 397.395
# INFO:tensorflow:loss = 0.68076, step = 4400 (0.252 sec)
# INFO:tensorflow:global_step/sec: 358.32
# INFO:tensorflow:loss = 0.6713483, step = 4500 (0.279 sec)
# INFO:tensorflow:global_step/sec: 404.89
# INFO:tensorflow:loss = 0.65800333, step = 4600 (0.247 sec)
# INFO:tensorflow:global_step/sec: 412.987
# INFO:tensorflow:loss = 0.67667246, step = 4700 (0.243 sec)
# INFO:tensorflow:global_step/sec: 409.333
# INFO:tensorflow:loss = 0.6496923, step = 4800 (0.243 sec)
# INFO:tensorflow:global_step/sec: 372.585
# INFO:tensorflow:loss = 0.67875576, step = 4900 (0.268 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into /var/folders/93/6v8bj28n2qd703tlw3s9vkb40000gn/T/tmp3_49jypx/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.66628367.

# %%
eval_result = classifier.evaluate(
    input_fn=lambda: input_fn(test, test_y, training=False)
)
print('\nTest set accuracy: {accuracy:0.3f}\n'.format(**eval_result))
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-07-09T23:13:19Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/93/6v8bj28n2qd703tlw3s9vkb40000gn/T/tmp3_49jypx/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-07-09-23:13:19
# INFO:tensorflow:Saving dict for global step 5000: accuracy = 0.53333336, average_loss = 0.8143413, global_step = 5000, loss = 0.8143413
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: /var/folders/93/6v8bj28n2qd703tlw3s9vkb40000gn/T/tmp3_49jypx/model.ckpt-5000
#
# Test set accuracy: 0.533

# %% [markdown]
# ### Predictions
