# %%
from tensorflow import keras
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
data = keras.datasets.fashion_mnist

# %%
(train_images, train_labels), (test_images, test_labels) = data.load_data()

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

train_images = train_images/255.0
test_images = test_images/255.0

plt.imshow(train_images[0], cmap=plt.cm.binary)
plt.show()

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation="relu"),
    keras.layers.Dense(10, activation="softmax")
])

# %%
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

model.fit(train_images, train_labels, epochs=5)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 4s 69us/sample - loss: 0.2786 - accuracy: 0.8965
# Epoch 2/5
# 60000/60000 [==============================] - 4s 63us/sample - loss: 0.2650 - accuracy: 0.9024
# Epoch 3/5
# 60000/60000 [==============================] - 4s 62us/sample - loss: 0.2531 - accuracy: 0.9049
# Epoch 4/5
# 60000/60000 [==============================] - 4s 62us/sample - loss: 0.2432 - accuracy: 0.9085
# Epoch 5/5
# 60000/60000 [==============================] - 4s 72us/sample - loss: 0.2353 - accuracy: 0.9119

# %%
# test_loss, test_acc = model.evaluate(test_images, test_labels)

# print(test_acc)

# %%
prediction = model.predict(test_images)
class_names[np.argmax(prediction[0])]
# Out:
# 'Ankle boot'

# %%
for i in range(5):
    plt.imshow(test_images[i], cmap=plt.cm.binary)
    plt.xlabel("Actual: " + class_names[test_labels[i]])
    plt.title('Prediction ' + class_names[np.argmax(prediction[i])])
    plt.show()
